# %%
# !sim="ONT.R10.4"; IsoQuant/isoquant.py -t 32 -d nanopore --stranded forward --fastq Mouse.${sim}.simulated.shuffled.fastq \
 --reference lrgasp_grcm39_sirvs.fasta --genedb lrgasp_gencode_vM27_sirvs.gtf.gz --complete_genedb \
 --output IsoQuant_Mouse_IQ_${sim} --prefix IsoQuant_Mouse_IQ_${sim}
# Out:
# 2024-02-26 23:06:49,763 - INFO - Running IsoQuant version 3.3.0
# 2024-02-26 23:06:49,764 - WARNING - Output folder already contains a previous run, some files may be overwritten. Use --resume to resume a failed run. Use --force to avoid this message. Press Ctrl+C to interrupt the run now.
# 2024-02-26 23:06:58,774 - INFO - Overwriting the previous run
# 2024-02-26 23:06:59,807 - WARNING - IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4 folder already exists, some files may be overwritten
# 2024-02-26 23:06:59,822 - WARNING - IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux folder already exists, some files may be overwritten
# 2024-02-26 23:06:59,824 - INFO - Novel unspliced transcripts will not be reported, set --report_novel_unspliced true to discover them
# 2024-02-26 23:06:59,825 - INFO -  === IsoQuant pipeline started ===
# 2024-02-26 23:06:59,825 - INFO - Converting gene annotation file to .db format (takes a while)...
# 2024-02-26 23:11:36,327 - INFO - Gene database written to /home/rebekah/IsoQuant_Mouse_IQ_ONT.R10.4/lrgasp_gencode_vM27_sirvs.gtf.db
# 2024-02-26 23:11:36,328 - INFO - Provide this database next time to avoid excessive conversion
# 2024-02-26 23:11:36,329 - INFO - Indexing reference
# 2024-02-26 23:13:25,855 - INFO - Converting gene annotation file /home/rebekah/IsoQuant_Mouse_IQ_ONT.R10.4/lrgasp_gencode_vM27_sirvs.gtf.db to .bed format
# 2024-02-26 23:14:24,351 - INFO - Gene database BED written to IsoQuant_Mouse_IQ_ONT.R10.4/lrgasp_gencode_vM27_sirvs.gtf.bed
# 2024-02-26 23:14:24,360 - INFO - Aligning /home/rebekah/Mouse.ONT.R10.4.simulated.shuffled.fastq to the reference, alignments will be saved to /home/rebekah/IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4_Mouse.ONT.R10.4.simulated.shuffled_925a22_492e73_af3813.bam
# 2024-02-26 23:14:24,361 - INFO - Running minimap2 (takes a while)
# 2024-02-27 01:53:20,823 - INFO - Sorting alignments
# 2024-02-27 02:04:40,809 - INFO - Indexing alignments
# 2024-02-27 02:06:48,316 - INFO - Loading gene database from /home/rebekah/IsoQuant_Mouse_IQ_ONT.R10.4/lrgasp_gencode_vM27_sirvs.gtf.db
# 2024-02-27 02:06:48,318 - INFO - Loading reference genome from /home/rebekah/lrgasp_grcm39_sirvs.fasta
# 2024-02-27 02:07:14,189 - INFO - Processing 1 sample
# 2024-02-27 02:07:14,189 - INFO - Processing sample IsoQuant_Mouse_IQ_ONT.R10.4
# 2024-02-27 02:07:14,189 - INFO - Sample has 1 BAM file: IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4_Mouse.ONT.R10.4.simulated.shuffled_925a22_492e73_af3813.bam
# 2024-02-27 02:07:14,190 - INFO - Collecting read alignments
# 2024-02-27 02:07:14,643 - INFO - Processing chromosome chr5_JH584299v1_random
# 2024-02-27 02:07:14,643 - INFO - Processing chromosome chr5_JH584297v1_random
# 2024-02-27 02:07:14,643 - INFO - Processing chromosome chr5_JH584296v1_random
# 2024-02-27 02:07:14,643 - INFO - Processing chromosome chr9
# 2024-02-27 02:07:14,644 - INFO - Processing chromosome chr14
# 2024-02-27 02:07:14,646 - INFO - Processing chromosome chr5_JH584298v1_random
# 2024-02-27 02:07:14,647 - INFO - Processing chromosome chr1_GL456211v1_random
# 2024-02-27 02:07:14,647 - INFO - Processing chromosome chr3
# 2024-02-27 02:07:14,648 - INFO - Processing chromosome chr15
# 2024-02-27 02:07:14,649 - INFO - Processing chromosome chr8
# 2024-02-27 02:07:14,649 - INFO - Processing chromosome chr10
# 2024-02-27 02:07:14,649 - INFO - Processing chromosome chrX
# 2024-02-27 02:07:14,649 - INFO - Processing chromosome chr2
# 2024-02-27 02:07:14,650 - INFO - Processing chromosome chr6
# 2024-02-27 02:07:14,650 - INFO - Processing chromosome chr4
# 2024-02-27 02:07:14,651 - INFO - Processing chromosome chr1
# 2024-02-27 02:07:14,656 - INFO - Processing chromosome chr7_GL456219v1_random
# 2024-02-27 02:07:14,666 - INFO - Processing chromosome chr11
# 2024-02-27 02:07:14,668 - INFO - Processing chromosome chr13
# 2024-02-27 02:07:14,668 - INFO - Processing chromosome chr18
# 2024-02-27 02:07:14,668 - INFO - Processing chromosome chr5
# 2024-02-27 02:07:14,682 - INFO - Processing chromosome chr1_GL456221v1_random
# 2024-02-27 02:07:14,682 - INFO - Processing chromosome chrY_JH584300v1_random
# 2024-02-27 02:07:14,682 - INFO - Processing chromosome chr12
# 2024-02-27 02:07:14,683 - INFO - Processing chromosome chrX_GL456233v2_random
# 2024-02-27 02:07:14,683 - INFO - Processing chromosome chr7
# 2024-02-27 02:07:14,685 - INFO - Processing chromosome chr17
# 2024-02-27 02:07:14,696 - INFO - Processing chromosome chrY
# 2024-02-27 02:07:14,696 - INFO - Processing chromosome chr19
# 2024-02-27 02:07:14,728 - INFO - Finished processing chromosome chrY_JH584300v1_random
# 2024-02-27 02:07:14,728 - INFO - Processing chromosome chrY_JH584301v1_random
# 2024-02-27 02:07:14,728 - INFO - Processing chromosome chr16
# 2024-02-27 02:07:14,728 - INFO - Processing chromosome chr5_GL456354v1_random
# 2024-02-27 02:07:14,746 - INFO - Finished processing chromosome chr5_JH584297v1_random
# 2024-02-27 02:07:14,795 - INFO - Finished processing chromosome chr7_GL456219v1_random
# 2024-02-27 02:07:14,795 - INFO - Finished processing chromosome chrY_JH584301v1_random
# 2024-02-27 02:07:14,801 - INFO - Processing chromosome chr1_GL456210v1_random
# 2024-02-27 02:07:14,806 - INFO - Finished processing chromosome chr5_JH584296v1_random
# 2024-02-27 02:07:14,816 - INFO - Processing chromosome chrY_JH584303v1_random
# 2024-02-27 02:07:14,817 - INFO - Finished processing chromosome chr1_GL456211v1_random
# 2024-02-27 02:07:14,828 - INFO - Processing chromosome chrY_JH584302v1_random
# 2024-02-27 02:07:14,845 - INFO - Processing chromosome chr1_GL456212v1_random
# 2024-02-27 02:07:14,852 - INFO - Processing chromosome SIRV7
# 2024-02-27 02:07:14,852 - INFO - Finished processing chromosome chrY_JH584302v1_random
# 2024-02-27 02:07:14,852 - INFO - Finished processing chromosome chr1_GL456221v1_random
# 2024-02-27 02:07:14,866 - INFO - Finished processing chromosome SIRV7
# 2024-02-27 02:07:14,873 - INFO - Processing chromosome chrUn_JH584304v1
# 2024-02-27 02:07:14,877 - INFO - Finished processing chromosome chr5_JH584298v1_random
# 2024-02-27 02:07:14,885 - INFO - Finished processing chromosome chr5_GL456354v1_random
# 2024-02-27 02:07:14,886 - INFO - Processing chromosome chrUn_GL456379v1
# 2024-02-27 02:07:14,889 - INFO - Processing chromosome chrUn_GL456366v1
# 2024-02-27 02:07:14,906 - INFO - Finished processing chromosome chrY_JH584303v1_random
# 2024-02-27 02:07:14,907 - INFO - Processing chromosome chrUn_GL456367v1
# 2024-02-27 02:07:14,908 - INFO - Processing chromosome chr1_GL456239v1_random
# 2024-02-27 02:07:14,916 - INFO - Processing chromosome chrUn_GL456383v1
# 2024-02-27 02:07:14,923 - INFO - Finished processing chromosome chr1_GL456239v1_random
# 2024-02-27 02:07:14,930 - INFO - Finished processing chromosome chrUn_GL456383v1
# 2024-02-27 02:07:14,930 - INFO - Finished processing chromosome chr1_GL456210v1_random
# 2024-02-27 02:07:14,933 - INFO - Finished processing chromosome chrUn_GL456367v1
# 2024-02-27 02:07:14,937 - INFO - Processing chromosome chrUn_GL456385v1
# 2024-02-27 02:07:14,940 - INFO - Finished processing chromosome chr5_JH584299v1_random
# 2024-02-27 02:07:14,943 - INFO - Finished processing chromosome chrUn_GL456379v1
# 2024-02-27 02:07:14,946 - INFO - Processing chromosome chrUn_GL456360v1
# 2024-02-27 02:07:14,951 - INFO - Finished processing chromosome chrUn_GL456385v1
# 2024-02-27 02:07:14,953 - INFO - Processing chromosome chrUn_GL456378v1
# 2024-02-27 02:07:14,956 - INFO - Finished processing chromosome chrUn_GL456366v1
# 2024-02-27 02:07:14,961 - INFO - Finished processing chromosome chrUn_GL456360v1
# 2024-02-27 02:07:14,968 - INFO - Finished processing chromosome chr1_GL456212v1_random
# 2024-02-27 02:07:14,969 - INFO - Processing chromosome chrUn_GL456389v1
# 2024-02-27 02:07:14,969 - INFO - Processing chromosome chrUn_MU069435v1
# 2024-02-27 02:07:14,970 - INFO - Processing chromosome chrUn_GL456372v1
# 2024-02-27 02:07:14,972 - INFO - Processing chromosome chrUn_GL456370v1
# 2024-02-27 02:07:14,979 - INFO - Finished processing chromosome chrX_GL456233v2_random
# 2024-02-27 02:07:14,980 - INFO - Processing chromosome chrUn_GL456381v1
# 2024-02-27 02:07:14,984 - INFO - Processing chromosome chrUn_GL456390v1
# 2024-02-27 02:07:14,984 - INFO - Finished processing chromosome chrUn_GL456372v1
# 2024-02-27 02:07:14,989 - INFO - Finished processing chromosome chrUn_GL456389v1
# 2024-02-27 02:07:14,990 - INFO - Finished processing chromosome chrUn_GL456370v1
# 2024-02-27 02:07:14,991 - INFO - Processing chromosome chrUn_GL456387v1
# 2024-02-27 02:07:14,995 - INFO - Finished processing chromosome chrUn_GL456381v1
# 2024-02-27 02:07:15,115 - INFO - Finished processing chromosome SIRV3
# 2024-02-27 02:07:15,122 - INFO - Processing chromosome SIRV8002
# 2024-02-27 02:07:15,128 - INFO - Finished processing chromosome SIRV8001
# 2024-02-27 02:07:15,132 - INFO - Processing chromosome SIRV2
# 2024-02-27 02:07:15,133 - INFO - Processing chromosome SIRV6002
# 2024-02-27 02:07:15,136 - INFO - Processing chromosome SIRV6001
# 2024-02-27 02:07:15,140 - INFO - Processing chromosome SIRV8003
# 2024-02-27 02:07:15,145 - INFO - Finished processing chromosome SIRV8002
# 2024-02-27 02:07:15,147 - INFO - Finished processing chromosome SIRV2
# 2024-02-27 02:07:15,148 - INFO - Finished processing chromosome SIRV6002
# 2024-02-27 02:07:15,151 - INFO - Processing chromosome SIRV6003
# 2024-02-27 02:07:15,154 - INFO - Finished processing chromosome SIRV6001
# 2024-02-27 02:07:15,159 - INFO - Processing chromosome SIRV4003
# 2024-02-27 02:07:15,162 - INFO - Finished processing chromosome SIRV8003
# 2024-02-27 02:07:15,170 - INFO - Processing chromosome SIRV4002
# 2024-02-27 02:07:15,172 - INFO - Processing chromosome ERCC-00033
# 2024-02-27 02:07:15,173 - INFO - Finished processing chromosome SIRV6003
# 2024-02-27 02:07:15,178 - INFO - Processing chromosome SIRV4001
# 2024-02-27 02:07:15,179 - INFO - Finished processing chromosome SIRV4003
# 2024-02-27 02:07:15,184 - INFO - Finished processing chromosome SIRV4002
# 2024-02-27 02:07:15,187 - INFO - Processing chromosome ERCC-00104
# 2024-02-27 02:07:15,187 - INFO - Finished processing chromosome ERCC-00033
# 2024-02-27 02:07:15,188 - INFO - Finished processing chromosome chr1_MU069434v1_random
# 2024-02-27 02:07:15,193 - INFO - Finished processing chromosome SIRV4001
# 2024-02-27 02:07:15,203 - INFO - Finished processing chromosome ERCC-00104
# 2024-02-27 02:07:15,206 - INFO - Processing chromosome ERCC-00025
# 2024-02-27 02:07:15,206 - INFO - Processing chromosome ERCC-00014
# 2024-02-27 02:07:15,207 - INFO - Processing chromosome chr4_JH584295v1_random
# 2024-02-27 02:07:15,210 - INFO - Processing chromosome ERCC-00099
# 2024-02-27 02:07:15,212 - INFO - Processing chromosome ERCC-00116
# 2024-02-27 02:07:15,221 - INFO - Finished processing chromosome chr4_JH584295v1_random
# 2024-02-27 02:07:15,221 - INFO - Finished processing chromosome ERCC-00014
# 2024-02-27 02:07:15,222 - INFO - Processing chromosome ERCC-00098
# 2024-02-27 02:07:15,224 - INFO - Processing chromosome ERCC-00044
# 2024-02-27 02:07:15,225 - INFO - Finished processing chromosome ERCC-00099
# 2024-02-27 02:07:15,227 - INFO - Processing chromosome ERCC-00031
# 2024-02-27 02:07:15,228 - INFO - Finished processing chromosome ERCC-00025
# 2024-02-27 02:07:15,236 - INFO - Finished processing chromosome ERCC-00098
# 2024-02-27 02:07:15,236 - INFO - Finished processing chromosome ERCC-00116
# 2024-02-27 02:07:15,241 - INFO - Finished processing chromosome ERCC-00031
# 2024-02-27 02:07:15,243 - INFO - Processing chromosome ERCC-00017
# 2024-02-27 02:07:15,244 - INFO - Processing chromosome ERCC-00041
# 2024-02-27 02:07:15,244 - INFO - Finished processing chromosome ERCC-00044
# 2024-02-27 02:07:15,249 - INFO - Processing chromosome ERCC-00069
# 2024-02-27 02:07:15,258 - INFO - Finished processing chromosome ERCC-00017
# 2024-02-27 02:07:15,259 - INFO - Finished processing chromosome ERCC-00041
# 2024-02-27 02:07:15,259 - INFO - Processing chromosome ERCC-00058
# 2024-02-27 02:07:15,265 - INFO - Finished processing chromosome ERCC-00069
# 2024-02-27 02:07:15,265 - INFO - Processing chromosome ERCC-00028
# 2024-02-27 02:07:15,269 - INFO - Processing chromosome ERCC-00061
# 2024-02-27 02:07:15,272 - INFO - Processing chromosome ERCC-00117
# 2024-02-27 02:07:15,274 - INFO - Finished processing chromosome ERCC-00058
# 2024-02-27 02:07:15,274 - INFO - Processing chromosome ERCC-00112
# 2024-02-27 02:07:15,282 - INFO - Processing chromosome ERCC-00035
# 2024-02-27 02:07:15,282 - INFO - Processing chromosome ERCC-00126
# 2024-02-27 02:07:15,286 - INFO - Finished processing chromosome ERCC-00117
# 2024-02-27 02:07:15,287 - INFO - Finished processing chromosome ERCC-00028
# 2024-02-27 02:07:15,288 - INFO - Processing chromosome ERCC-00092
# 2024-02-27 02:07:15,290 - INFO - Finished processing chromosome ERCC-00061
# 2024-02-27 02:07:15,297 - INFO - Finished processing chromosome ERCC-00126
# 2024-02-27 02:07:15,297 - INFO - Finished processing chromosome ERCC-00112
# 2024-02-27 02:07:15,297 - INFO - Finished processing chromosome ERCC-00035
# 2024-02-27 02:07:15,300 - INFO - Processing chromosome ERCC-00096
# 2024-02-27 02:07:15,303 - INFO - Finished processing chromosome ERCC-00092
# 2024-02-27 02:07:15,310 - INFO - Processing chromosome ERCC-00130
# 2024-02-27 02:07:15,315 - INFO - Finished processing chromosome ERCC-00096
# 2024-02-27 02:07:15,320 - INFO - Processing chromosome ERCC-00145
# 2024-02-27 02:07:15,320 - INFO - Processing chromosome ERCC-00057
# 2024-02-27 02:07:15,323 - INFO - Processing chromosome ERCC-00136
# 2024-02-27 02:07:15,323 - INFO - Processing chromosome ERCC-00002
# 2024-02-27 02:07:15,324 - INFO - Finished processing chromosome ERCC-00130
# 2024-02-27 02:07:15,326 - INFO - Processing chromosome ERCC-00086
# 2024-02-27 02:07:15,335 - INFO - Finished processing chromosome ERCC-00145
# 2024-02-27 02:07:15,335 - INFO - Finished processing chromosome ERCC-00057
# 2024-02-27 02:07:15,336 - INFO - Processing chromosome ERCC-00083
# 2024-02-27 02:07:15,339 - INFO - Processing chromosome ERCC-00158
# 2024-02-27 02:07:15,341 - INFO - Finished processing chromosome ERCC-00086
# 2024-02-27 02:07:15,345 - INFO - Finished processing chromosome ERCC-00136
# 2024-02-27 02:07:15,346 - INFO - Finished processing chromosome ERCC-00002
# 2024-02-27 02:07:15,350 - INFO - Processing chromosome ERCC-00003
# 2024-02-27 02:07:15,355 - INFO - Finished processing chromosome ERCC-00158
# 2024-02-27 02:07:15,358 - INFO - Finished processing chromosome ERCC-00083
# 2024-02-27 02:07:15,360 - INFO - Processing chromosome ERCC-00042
# 2024-02-27 02:07:15,365 - INFO - Processing chromosome ERCC-00053
# 2024-02-27 02:07:15,371 - INFO - Processing chromosome ERCC-00043
# 2024-02-27 02:07:15,372 - INFO - Finished processing chromosome ERCC-00003
# 2024-02-27 02:07:15,375 - INFO - Finished processing chromosome ERCC-00042
# 2024-02-27 02:07:15,375 - INFO - Processing chromosome ERCC-00062
# 2024-02-27 02:07:15,378 - INFO - Processing chromosome ERCC-00147
# 2024-02-27 02:07:15,378 - INFO - Finished processing chromosome ERCC-00053
# 2024-02-27 02:07:15,383 - INFO - Processing chromosome ERCC-00075
# 2024-02-27 02:07:15,388 - INFO - Finished processing chromosome ERCC-00043
# 2024-02-27 02:07:15,390 - INFO - Finished processing chromosome ERCC-00062
# 2024-02-27 02:07:15,393 - INFO - Finished processing chromosome ERCC-00147
# 2024-02-27 02:07:15,395 - INFO - Processing chromosome ERCC-00164
# 2024-02-27 02:07:15,399 - INFO - Processing chromosome ERCC-00170
# 2024-02-27 02:07:15,402 - INFO - Processing chromosome ERCC-00123
# 2024-02-27 02:07:15,407 - INFO - Finished processing chromosome ERCC-00075
# 2024-02-27 02:07:15,409 - INFO - Processing chromosome ERCC-00168
# 2024-02-27 02:07:15,411 - INFO - Finished processing chromosome ERCC-00164
# 2024-02-27 02:07:15,412 - INFO - Processing chromosome ERCC-00108
# 2024-02-27 02:07:15,414 - INFO - Finished processing chromosome ERCC-00170
# 2024-02-27 02:07:15,415 - INFO - Processing chromosome ERCC-00138
# 2024-02-27 02:07:15,416 - INFO - Finished processing chromosome ERCC-00123
# 2024-02-27 02:07:15,416 - INFO - Processing chromosome ERCC-00034
# 2024-02-27 02:07:15,427 - INFO - Finished processing chromosome ERCC-00108
# 2024-02-27 02:07:15,430 - INFO - Finished processing chromosome ERCC-00034
# 2024-02-27 02:07:15,431 - INFO - Finished processing chromosome ERCC-00168
# 2024-02-27 02:07:15,436 - INFO - Finished processing chromosome ERCC-00138
# 2024-02-27 02:07:15,438 - INFO - Processing chromosome ERCC-00084
# 2024-02-27 02:07:15,441 - INFO - Processing chromosome ERCC-00157
# 2024-02-27 02:07:15,446 - INFO - Processing chromosome ERCC-00012
# 2024-02-27 02:07:15,450 - INFO - Processing chromosome ERCC-00111
# 2024-02-27 02:07:15,452 - INFO - Finished processing chromosome ERCC-00084
# 2024-02-27 02:07:15,453 - INFO - Processing chromosome ERCC-00078
# 2024-02-27 02:07:15,454 - INFO - Processing chromosome ERCC-00048
# 2024-02-27 02:07:15,461 - INFO - Processing chromosome ERCC-00165
# 2024-02-27 02:07:15,462 - INFO - Finished processing chromosome ERCC-00012
# 2024-02-27 02:07:15,464 - INFO - Finished processing chromosome ERCC-00157
# 2024-02-27 02:07:15,465 - INFO - Finished processing chromosome ERCC-00111
# 2024-02-27 02:07:15,468 - INFO - Processing chromosome ERCC-00009
# 2024-02-27 02:07:15,468 - INFO - Finished processing chromosome ERCC-00078
# 2024-02-27 02:07:15,469 - INFO - Finished processing chromosome ERCC-00048
# 2024-02-27 02:07:15,476 - INFO - Processing chromosome ERCC-00016
# 2024-02-27 02:07:15,476 - INFO - Finished processing chromosome ERCC-00165
# 2024-02-27 02:07:15,486 - INFO - Processing chromosome ERCC-00085
# 2024-02-27 02:07:15,487 - INFO - Processing chromosome ERCC-00113
# 2024-02-27 02:07:15,490 - INFO - Finished processing chromosome ERCC-00016
# 2024-02-27 02:07:15,491 - INFO - Finished processing chromosome ERCC-00009
# 2024-02-27 02:07:15,492 - INFO - Processing chromosome ERCC-00143
# 2024-02-27 02:07:15,494 - INFO - Processing chromosome ERCC-00131
# 2024-02-27 02:07:15,497 - INFO - Processing chromosome ERCC-00013
# 2024-02-27 02:07:15,501 - INFO - Finished processing chromosome ERCC-00085
# 2024-02-27 02:07:15,502 - INFO - Finished processing chromosome ERCC-00113
# 2024-02-27 02:07:15,506 - INFO - Finished processing chromosome ERCC-00143
# 2024-02-27 02:07:15,510 - INFO - Finished processing chromosome ERCC-00131
# 2024-02-27 02:07:15,512 - INFO - Processing chromosome ERCC-00040
# 2024-02-27 02:07:15,513 - INFO - Processing chromosome ERCC-00022
# 2024-02-27 02:07:15,519 - INFO - Finished processing chromosome ERCC-00013
# 2024-02-27 02:07:15,525 - INFO - Processing chromosome ERCC-00150
# 2024-02-27 02:07:15,525 - INFO - Processing chromosome ERCC-00160
# 2024-02-27 02:07:15,526 - INFO - Finished processing chromosome ERCC-00040
# 2024-02-27 02:07:15,528 - INFO - Finished processing chromosome ERCC-00022
# 2024-02-27 02:07:15,529 - INFO - Processing chromosome ERCC-00039
# 2024-02-27 02:07:15,529 - INFO - Processing chromosome ERCC-00067
# 2024-02-27 02:07:15,536 - INFO - Processing chromosome ERCC-00079
# 2024-02-27 02:07:15,540 - INFO - Finished processing chromosome ERCC-00150
# 2024-02-27 02:07:15,540 - INFO - Finished processing chromosome ERCC-00160
# 2024-02-27 02:07:15,543 - INFO - Finished processing chromosome ERCC-00039
# 2024-02-27 02:07:15,543 - INFO - Finished processing chromosome ERCC-00067
# 2024-02-27 02:07:15,549 - INFO - Processing chromosome ERCC-00071
# 2024-02-27 02:07:15,551 - INFO - Finished processing chromosome ERCC-00079
# 2024-02-27 02:07:15,551 - INFO - Processing chromosome ERCC-00076
# 2024-02-27 02:07:15,552 - INFO - Processing chromosome ERCC-00019
# 2024-02-27 02:07:15,563 - INFO - Processing chromosome ERCC-00073
# 2024-02-27 02:07:15,564 - INFO - Finished processing chromosome ERCC-00071
# 2024-02-27 02:07:15,564 - INFO - Processing chromosome ERCC-00163
# 2024-02-27 02:07:15,565 - INFO - Finished processing chromosome ERCC-00076
# 2024-02-27 02:07:15,565 - INFO - Processing chromosome ERCC-00144
# 2024-02-27 02:07:15,565 - INFO - Processing chromosome ERCC-00137
# 2024-02-27 02:07:15,572 - INFO - Finished processing chromosome ERCC-00019
# 2024-02-27 02:07:15,578 - INFO - Processing chromosome ERCC-00154
# 2024-02-27 02:07:15,578 - INFO - Finished processing chromosome ERCC-00073
# 2024-02-27 02:07:15,580 - INFO - Finished processing chromosome ERCC-00137
# 2024-02-27 02:07:15,581 - INFO - Finished processing chromosome ERCC-00144
# 2024-02-27 02:07:15,586 - INFO - Processing chromosome ERCC-00109
# 2024-02-27 02:07:15,587 - INFO - Finished processing chromosome ERCC-00163
# 2024-02-27 02:07:15,589 - INFO - Processing chromosome ERCC-00120
# 2024-02-27 02:07:15,594 - INFO - Finished processing chromosome ERCC-00154
# 2024-02-27 02:07:15,601 - INFO - Finished processing chromosome ERCC-00109
# 2024-02-27 02:07:15,602 - INFO - Processing chromosome ERCC-00081
# 2024-02-27 02:07:15,603 - INFO - Processing chromosome ERCC-00095
# 2024-02-27 02:07:15,607 - INFO - Processing chromosome ERCC-00024
# 2024-02-27 02:07:15,607 - INFO - Finished processing chromosome ERCC-00120
# 2024-02-27 02:07:15,607 - INFO - Processing chromosome ERCC-00059
# 2024-02-27 02:07:15,617 - INFO - Finished processing chromosome ERCC-00081
# 2024-02-27 02:07:15,617 - INFO - Finished processing chromosome ERCC-00095
# 2024-02-27 02:07:15,621 - INFO - Processing chromosome ERCC-00162
# 2024-02-27 02:07:15,625 - INFO - Processing chromosome ERCC-00046
# 2024-02-27 02:07:15,634 - INFO - Finished processing chromosome ERCC-00024
# 2024-02-27 02:07:15,636 - INFO - Processing chromosome ERCC-00004
# 2024-02-27 02:07:15,636 - INFO - Finished processing chromosome ERCC-00059
# 2024-02-27 02:07:15,637 - INFO - Finished processing chromosome ERCC-00162
# 2024-02-27 02:07:15,642 - INFO - Processing chromosome ERCC-00097
# 2024-02-27 02:07:15,646 - INFO - Processing chromosome ERCC-00060
# 2024-02-27 02:07:15,648 - INFO - Finished processing chromosome ERCC-00046
# 2024-02-27 02:07:15,649 - INFO - Processing chromosome ERCC-00074
# 2024-02-27 02:07:15,658 - INFO - Finished processing chromosome ERCC-00097
# 2024-02-27 02:07:15,667 - INFO - Finished processing chromosome ERCC-00004
# 2024-02-27 02:07:15,670 - INFO - Finished processing chromosome ERCC-00060
# 2024-02-27 02:07:15,677 - INFO - Finished processing chromosome ERCC-00074
# 2024-02-27 02:07:15,681 - INFO - Processing chromosome ERCC-00051
# 2024-02-27 02:07:15,682 - INFO - Processing chromosome ERCC-00142
# 2024-02-27 02:07:15,684 - INFO - Processing chromosome ERCC-00148
# 2024-02-27 02:07:15,684 - INFO - Processing chromosome ERCC-00171
# 2024-02-27 02:07:15,685 - INFO - Processing chromosome ERCC-00156
# 2024-02-27 02:07:15,695 - INFO - Processing chromosome ERCC-00077
# 2024-02-27 02:07:15,699 - INFO - Finished processing chromosome ERCC-00156
# 2024-02-27 02:07:15,700 - INFO - Processing chromosome ERCC-00134
# 2024-02-27 02:07:15,701 - INFO - Finished processing chromosome ERCC-00051
# 2024-02-27 02:07:15,704 - INFO - Finished processing chromosome ERCC-00142
# 2024-02-27 02:07:15,706 - INFO - Finished processing chromosome ERCC-00148
# 2024-02-27 02:07:15,709 - INFO - Finished processing chromosome ERCC-00077
# 2024-02-27 02:07:15,713 - INFO - Processing chromosome ERCC-00054
# 2024-02-27 02:07:15,716 - INFO - Finished processing chromosome ERCC-00134
# 2024-02-27 02:07:15,730 - INFO - Finished processing chromosome ERCC-00054
# 2024-02-27 02:07:15,742 - INFO - Finished processing chromosome ERCC-00171
# 2024-02-27 02:07:15,884 - INFO - Finished processing chromosome chrUn_JH584304v1
# 2024-02-27 02:07:15,895 - INFO - Finished processing chromosome chrUn_GL456382v1
# 2024-02-27 02:07:56,076 - INFO - Finished processing chromosome chrY
# 2024-02-27 02:14:50,925 - INFO - Finished processing chromosome chrM
# 2024-02-27 02:51:50,344 - INFO - Finished processing chromosome chr19
# 2024-02-27 02:53:47,530 - INFO - Finished processing chromosome chrX
# 2024-02-27 03:01:05,914 - INFO - Finished processing chromosome chr18
# 2024-02-27 03:05:49,975 - INFO - Finished processing chromosome chr13
# 2024-02-27 03:09:38,248 - INFO - Finished processing chromosome chr16
# 2024-02-27 03:11:45,757 - INFO - Finished processing chromosome chr14
# 2024-02-27 03:18:21,729 - INFO - Finished processing chromosome chr17
# 2024-02-27 03:21:32,684 - INFO - Finished processing chromosome chr3
# 2024-02-27 03:22:36,455 - INFO - Finished processing chromosome chr15
# 2024-02-27 03:25:26,780 - INFO - Finished processing chromosome chr10
# 2024-02-27 03:28:03,323 - INFO - Finished processing chromosome chr6
# 2024-02-27 03:29:44,328 - INFO - Finished processing chromosome chr12
# 2024-02-27 03:32:15,009 - INFO - Finished processing chromosome chr8
# 2024-02-27 03:37:21,718 - INFO - Finished processing chromosome chr9
# 2024-02-27 03:39:29,080 - INFO - Finished processing chromosome chr4
# 2024-02-27 03:48:54,313 - INFO - Finished processing chromosome chr7
# 2024-02-27 03:49:00,657 - INFO - Finished processing chromosome chr5
# 2024-02-27 03:57:43,687 - INFO - Finished processing chromosome chr11
# 2024-02-27 03:58:40,005 - INFO - Finished processing chromosome chr1
# 2024-02-27 04:09:16,499 - INFO - Finished processing chromosome chr2
# 2024-02-27 04:12:41,586 - INFO - Resolving multimappers
# 2024-02-27 04:15:04,971 - INFO - Finishing read assignment, total assignments 30915003, polyA percentage 76.7
# 2024-02-27 04:15:31,849 - INFO - Read assignments files saved to IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save*.
# 2024-02-27 04:15:31,849 - INFO - To keep these intermediate files for debug purposes use --keep_tmp flag
# 2024-02-27 04:15:31,926 - INFO - Total alignments processed: 30915003, polyA tail detected in 23700177 (76.7%)
# 2024-02-27 04:15:31,927 - INFO - Processing assigned reads IsoQuant_Mouse_IQ_ONT.R10.4
# 2024-02-27 04:15:34,364 - INFO - Processing chromosome chr1
# 2024-02-27 04:15:34,367 - INFO - Processing chromosome chr3
# 2024-02-27 04:15:34,367 - INFO - Processing chromosome chrX
# 2024-02-27 04:15:34,367 - INFO - Processing chromosome chr4
# 2024-02-27 04:15:34,367 - INFO - Processing chromosome chr2
# 2024-02-27 04:15:34,368 - INFO - Processing chromosome chr5
# 2024-02-27 04:15:34,368 - INFO - Processing chromosome chr6
# 2024-02-27 04:15:34,369 - INFO - Processing chromosome chr7
# 2024-02-27 04:15:34,369 - INFO - Processing chromosome chr10
# 2024-02-27 04:15:34,369 - INFO - Processing chromosome chr8
# 2024-02-27 04:15:34,370 - INFO - Processing chromosome chr11
# 2024-02-27 04:15:34,370 - INFO - Processing chromosome chr14
# 2024-02-27 04:15:34,370 - INFO - Processing chromosome chr9
# 2024-02-27 04:15:34,371 - INFO - Processing chromosome chr12
# 2024-02-27 04:15:34,372 - INFO - Processing chromosome chr13
# 2024-02-27 04:15:34,375 - INFO - Processing chromosome chr15
# 2024-02-27 04:15:34,378 - INFO - Processing chromosome chr16
# 2024-02-27 04:15:34,381 - INFO - Processing chromosome chr17
# 2024-02-27 04:15:34,385 - INFO - Processing chromosome chr19
# 2024-02-27 04:15:34,386 - INFO - Processing chromosome chr18
# 2024-02-27 04:15:34,396 - INFO - Processing chromosome chr5_JH584298v1_random
# 2024-02-27 04:15:34,396 - INFO - Processing chromosome chrY_JH584300v1_random
# 2024-02-27 04:15:34,396 - INFO - Processing chromosome chr1_GL456221v1_random
# 2024-02-27 04:15:34,399 - INFO - Processing chromosome chr7_GL456219v1_random
# 2024-02-27 04:15:34,399 - INFO - Processing chromosome chrX_GL456233v2_random
# 2024-02-27 04:15:34,399 - INFO - Processing chromosome chr5_JH584299v1_random
# 2024-02-27 04:15:34,399 - INFO - Processing chromosome chr5_JH584296v1_random
# 2024-02-27 04:15:34,400 - INFO - Processing chromosome chrY_JH584301v1_random
# 2024-02-27 04:15:34,400 - INFO - Processing chromosome chr5_JH584297v1_random
# 2024-02-27 04:15:34,400 - INFO - Processing chromosome chrY
# 2024-02-27 04:15:34,401 - INFO - Processing chromosome chr5_GL456354v1_random
# 2024-02-27 04:15:34,401 - INFO - Processing chromosome chr1_GL456211v1_random
# 2024-02-27 04:15:34,431 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chrY_JH584300v1_random
# 2024-02-27 04:15:34,432 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr5_JH584298v1_random
# 2024-02-27 04:15:34,434 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr5_JH584297v1_random
# 2024-02-27 04:15:34,447 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chrY_JH584301v1_random
# 2024-02-27 04:15:34,447 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr7_GL456219v1_random
# 2024-02-27 04:15:34,448 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr1_GL456221v1_random
# 2024-02-27 04:15:34,448 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr5_GL456354v1_random
# 2024-02-27 04:15:34,448 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chrX_GL456233v2_random
# 2024-02-27 04:15:34,448 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr5_JH584296v1_random
# 2024-02-27 04:15:34,448 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr1_GL456211v1_random
# 2024-02-27 04:15:34,448 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/aux/IsoQuant_Mouse_IQ_ONT.R10.4.save_chr5_JH584299v1_random
# 2024-02-27 04:15:34,505 - INFO - Finished processing chromosome chr5_JH584298v1_random
# 2024-02-27 04:15:34,505 - INFO - Finished processing chromosome chr1_GL456221v1_random
# 2024-02-27 04:15:34,506 - INFO - Processing chromosome chr1_GL456210v1_random
# 2024-02-27 04:15:34,506 - INFO - Processing chromosome chrY_JH584303v1_random
# 2024-02-27 04:15:34,506 - INFO - Finished processing chromosome chr5_JH584299v1_random
# 2024-02-27 04:15:34,507 - INFO - Finished processing chromosome chrY_JH584300v1_random
# 2024-02-27 04:15:34,507 - INFO - Finished processing chromosome chrX_GL456233v2_random
# 2024-02-27 04:15:34,508 - INFO - Finished processing chromosome chr5_JH584296v1_random
soQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4.extended_annotation.gtf
# 2024-02-27 04:30:27,695 - INFO - Transcript model statistics
# 2024-02-27 04:30:27,695 - INFO - known: 30781
# 2024-02-27 04:30:27,695 - INFO - novel_in_catalog: 63
# 2024-02-27 04:30:27,695 - INFO - novel_not_in_catalog: 3074
# 2024-02-27 04:31:15,652 - INFO - Gene counts are stored in IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4.gene_counts.tsv
# 2024-02-27 04:31:15,652 - INFO - Transcript counts are stored in IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4.transcript_counts.tsv
# 2024-02-27 04:31:15,652 - INFO - Read assignments are stored in IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4/IsoQuant_Mouse_IQ_ONT.R10.4.read_assignments.tsv
# 2024-02-27 04:31:15,652 - INFO - Read assignment statistics
# 2024-02-27 04:31:15,653 - INFO - ambiguous: 9808813
# 2024-02-27 04:31:15,653 - INFO - inconsistent: 234384
# 2024-02-27 04:31:15,653 - INFO - intergenic: 1056
# 2024-02-27 04:31:15,653 - INFO - noninformative: 77843
# 2024-02-27 04:31:15,653 - INFO - unique: 17983860
# 2024-02-27 04:31:15,653 - INFO - unique_minor_difference: 2809047
# 2024-02-27 04:31:19,980 - INFO - Processed sample IsoQuant_Mouse_IQ_ONT.R10.4
# 2024-02-27 04:31:19,980 - INFO - Processed 1 sample
# 2024-02-27 04:31:19,980 - INFO -  === IsoQuant pipeline finished ===

# %%
# !sim="PB"; IsoQuant/isoquant.py -t 32 -d pacbio --stranded forward --fastq Mouse.${sim}.simulated.shuffled.fastq \
 --reference lrgasp_grcm39_sirvs.fasta --genedb lrgasp_gencode_vM27_sirvs.gtf --complete_genedb \
 --output IsoQuant_Mouse_IQ_${sim} --prefix IsoQuant_Mouse_IQ_${sim}
# Out:
# 2024-05-08 12:58:53,394 - INFO - Running IsoQuant version 3.3.0
# 2024-05-08 12:58:53,395 - WARNING - Output folder already contains a previous run, some files may be overwritten. Use --resume to resume a failed run. Use --force to avoid this message. Press Ctrl+C to interrupt the run now.
# 2024-05-08 12:59:02,396 - INFO - Overwriting the previous run
# 2024-05-08 12:59:03,449 - WARNING - IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB folder already exists, some files may be overwritten
# 2024-05-08 12:59:03,449 - WARNING - IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux folder already exists, some files may be overwritten
# 2024-05-08 12:59:03,484 - INFO -  === IsoQuant pipeline started ===
# 2024-05-08 12:59:03,497 - INFO - Converting gene annotation file to .db format (takes a while)...
# 2024-05-08 13:02:16,432 - INFO - Gene database written to /home/rebekah/IsoQuant_Mouse_IQ_PB/lrgasp_gencode_vM27_sirvs.db
# 2024-05-08 13:02:16,434 - INFO - Provide this database next time to avoid excessive conversion
# 2024-05-08 13:02:16,448 - INFO - Indexing reference
# 2024-05-08 13:03:54,759 - INFO - Converting gene annotation file /home/rebekah/IsoQuant_Mouse_IQ_PB/lrgasp_gencode_vM27_sirvs.db to .bed format
# 2024-05-08 13:04:37,693 - INFO - Gene database BED written to IsoQuant_Mouse_IQ_PB/lrgasp_gencode_vM27_sirvs.bed
# 2024-05-08 13:04:37,770 - INFO - Aligning /home/rebekah/Mouse.PB.simulated.shuffled.fastq to the reference, alignments will be saved to /home/rebekah/IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB_Mouse.PB.simulated.shuffled_ff2e6b_43e42d_71f5d0.bam
# 2024-05-08 13:04:37,770 - INFO - Running minimap2 (takes a while)
# 2024-05-08 13:45:26,541 - INFO - Sorting alignments
# 2024-05-08 13:49:36,632 - INFO - Indexing alignments
# 2024-05-08 13:51:13,484 - INFO - Loading gene database from /home/rebekah/IsoQuant_Mouse_IQ_PB/lrgasp_gencode_vM27_sirvs.db
# 2024-05-08 13:51:13,485 - INFO - Loading reference genome from /home/rebekah/lrgasp_grcm39_sirvs.fasta
# 2024-05-08 13:51:13,615 - INFO - Processing 1 sample
# 2024-05-08 13:51:13,615 - INFO - Processing sample IsoQuant_Mouse_IQ_PB
# 2024-05-08 13:51:13,615 - INFO - Sample has 1 BAM file: IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB_Mouse.PB.simulated.shuffled_ff2e6b_43e42d_71f5d0.bam
# 2024-05-08 13:51:13,616 - INFO - Collecting read alignments
# 2024-05-08 13:51:13,960 - INFO - Processing chromosome chrX
# 2024-05-08 13:51:13,967 - INFO - Processing chromosome chr12
# 2024-05-08 13:51:13,967 - INFO - Processing chromosome chr1_GL456211v1_random
# 2024-05-08 13:51:13,967 - INFO - Processing chromosome chr6
# 2024-05-08 13:51:13,968 - INFO - Processing chromosome chr10
# 2024-05-08 13:51:13,968 - INFO - Processing chromosome chr17
# 2024-05-08 13:51:13,968 - INFO - Processing chromosome chr5_JH584297v1_random
# 2024-05-08 13:51:13,968 - INFO - Processing chromosome chrY_JH584300v1_random
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chrX_GL456233v2_random
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chr5_JH584296v1_random
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chr16
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chr18
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chr5_JH584299v1_random
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chrY
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chr7_GL456219v1_random
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chr19
# 2024-05-08 13:51:13,969 - INFO - Processing chromosome chr5_JH584298v1_random
# 2024-05-08 13:51:13,971 - INFO - Processing chromosome chr11
# 2024-05-08 13:51:13,972 - INFO - Processing chromosome chr5
# 2024-05-08 13:51:13,973 - INFO - Processing chromosome chr1
# 2024-05-08 13:51:13,974 - INFO - Processing chromosome chr2
# 2024-05-08 13:51:13,974 - INFO - Processing chromosome chr7
# 2024-05-08 13:51:13,974 - INFO - Processing chromosome chr15
# 2024-05-08 13:51:13,975 - INFO - Processing chromosome chr9
# 2024-05-08 13:51:13,975 - INFO - Processing chromosome chr5_GL456354v1_random
# 2024-05-08 13:51:13,976 - INFO - Processing chromosome chrY_JH584301v1_random
# 2024-05-08 13:51:13,976 - INFO - Processing chromosome chr3
# 2024-05-08 13:51:13,976 - INFO - Processing chromosome chr1_GL456221v1_random
# 2024-05-08 13:51:13,976 - INFO - Processing chromosome chr4
# 2024-05-08 13:51:13,976 - INFO - Processing chromosome chr8
# 2024-05-08 13:51:13,976 - INFO - Processing chromosome chr13
# 2024-05-08 13:51:13,978 - INFO - Finished processing chromosome chr1_GL456211v1_random
# 2024-05-08 13:51:13,978 - INFO - Processing chromosome chr14
# 2024-05-08 13:51:13,978 - INFO - Finished processing chromosome chrY_JH584300v1_random
# 2024-05-08 13:51:13,979 - INFO - Finished processing chromosome chr5_JH584297v1_random
# 2024-05-08 13:51:13,979 - INFO - Finished processing chromosome chr5_JH584299v1_random
# 2024-05-08 13:51:13,979 - INFO - Finished processing chromosome chr5_JH584296v1_random
- INFO - Loading read assignments from IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB.save_chr9
# 2024-05-08 14:28:57,450 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB.save_chr11
# 2024-05-08 14:28:57,508 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB.save_chr5
# 2024-05-08 14:28:57,545 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB.save_chr2
# 2024-05-08 14:28:57,577 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB.save_chrM
# 2024-05-08 14:28:57,705 - INFO - Loading read assignments from IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/aux/IsoQuant_Mouse_IQ_PB.save_chr1
# 2024-05-08 14:29:19,774 - INFO - Finished processing chromosome chrM
# 2024-05-08 14:29:32,443 - INFO - Finished processing chromosome chr13
# 2024-05-08 14:29:33,048 - INFO - Finished processing chromosome chr16
# 2024-05-08 14:29:34,714 - INFO - Finished processing chromosome chr18
# 2024-05-08 14:29:35,666 - INFO - Finished processing chromosome chr19
# 2024-05-08 14:29:38,022 - INFO - Finished processing chromosome chr14
# 2024-05-08 14:29:39,799 - INFO - Finished processing chromosome chrX
# 2024-05-08 14:29:45,120 - INFO - Finished processing chromosome chr3
# 2024-05-08 14:29:45,456 - INFO - Finished processing chromosome chr12
# 2024-05-08 14:29:48,696 - INFO - Finished processing chromosome chr6
# 2024-05-08 14:29:52,380 - INFO - Finished processing chromosome chr15
# 2024-05-08 14:29:54,654 - INFO - Finished processing chromosome chr17
# 2024-05-08 14:29:56,003 - INFO - Finished processing chromosome chr10
# 2024-05-08 14:29:58,875 - INFO - Finished processing chromosome chr8
# 2024-05-08 14:30:04,343 - INFO - Finished processing chromosome chr9
# 2024-05-08 14:30:07,641 - INFO - Finished processing chromosome chr4
# 2024-05-08 14:30:09,188 - INFO - Finished processing chromosome chr1
# 2024-05-08 14:30:10,471 - INFO - Finished processing chromosome chr5
# 2024-05-08 14:30:30,600 - INFO - Finished processing chromosome chr2
# 2024-05-08 14:30:33,548 - INFO - Finished processing chromosome chr7
# 2024-05-08 14:30:36,793 - INFO - Finished processing chromosome chr11
# 2024-05-08 14:30:38,225 - INFO - Transcript model file IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB.transcript_models.gtf
# 2024-05-08 14:30:38,666 - INFO - Extended annotation is saved to IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB.extended_annotation.gtf
# 2024-05-08 14:30:38,666 - INFO - Transcript model statistics
# 2024-05-08 14:30:38,666 - INFO - known: 34017
# 2024-05-08 14:30:38,666 - INFO - novel_in_catalog: 45
# 2024-05-08 14:30:38,666 - INFO - novel_not_in_catalog: 1634
# 2024-05-08 14:30:48,543 - INFO - Gene counts are stored in IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB.gene_counts.tsv
# 2024-05-08 14:30:48,543 - INFO - Transcript counts are stored in IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB.transcript_counts.tsv
# 2024-05-08 14:30:48,543 - INFO - Read assignments are stored in IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB/IsoQuant_Mouse_IQ_PB.read_assignments.tsv
# 2024-05-08 14:30:48,543 - INFO - Read assignment statistics
# 2024-05-08 14:30:48,543 - INFO - ambiguous: 193500
# 2024-05-08 14:30:48,543 - INFO - inconsistent: 23259
# 2024-05-08 14:30:48,543 - INFO - intergenic: 141
# 2024-05-08 14:30:48,543 - INFO - noninformative: 396
# 2024-05-08 14:30:48,543 - INFO - unique: 4841191
# 2024-05-08 14:30:48,543 - INFO - unique_minor_difference: 969903
# 2024-05-08 14:30:49,386 - INFO - Processed sample IsoQuant_Mouse_IQ_PB
# 2024-05-08 14:30:49,386 - INFO - Processed 1 sample
# 2024-05-08 14:30:49,386 - INFO -  === IsoQuant pipeline finished ===

# %%
'''
#bambu Run 
library(bambu)

fa.file <- "/home/rebekah/lrgasp_grcm39_sirvs.fasta"

gtf.file <- "/home/rebekah/lrgasp_gencode_vM27_sirvs.gtf"

bambuAnnotations <- prepareAnnotations(gtf.file)

se <- bambu(reads = path_to_bam_generated_by_IsoQuant, annotations = bambuAnnotations, genome = fa.file, discovery = FALSE)
writeBambuOutput(se, path = "output_path")
'''

# %%
'''
#Oarfish run
import os

def run(cdna_ref, bs, fastq):
    os.system("./LRGASP_data/minimap2-2.28_x64-linux/minimap2 -t 32 -ax map-ont -N 100 "+cdna_ref+" "+fastq+" > "+bs+".sam")
    os.system("samtools view -bS -o "+bs+".bam "+bs+".sam")
    os.system("oarfish --alignments "+bs+".bam --threads 32 --output "+bs+"_oarfish --model-coverage --filter-group no-filters")

run("ref/LRGASP.cdna.fa", sim+"_Oarfish", "Mouse."+sim+".simulated.shuffled.fastq")
'''

# %%
#${kallisto} index -i LRGASP.k-${k}.v-13.idx -k ${k} LRGASP.cdna.fasta
 #'PB' #'ONT.R10.4'
#--long --error-rate $er --threshold 0.8
# !kallisto='/home/rebekah/kallisto_devel/kallisto/build/src/kallisto';\
 bustools='bustools/build/src/bustools';\
 k=63;\
 sim='PB';\
 ${kallisto} bus -t 30 -x bulk --long --threshold 0.8 \
 -i LRGASP.k-${k}.v-13.idx Mouse.${sim}.simulated.shuffled.fastq.gz \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er; \
 ${bustools} sort -t 30 Mouse.${sim}.simulated.shuffled._k-${k}_er/output.bus \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er/sorted.bus; \
 ${bustools} count -t 30 Mouse.${sim}.simulated.shuffled._k-${k}_er/sorted.bus \
 -t Mouse.${sim}.simulated.shuffled._k-${k}_er/transcripts.txt \
 -e Mouse.${sim}.simulated.shuffled._k-${k}_er/matrix.ec \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er/count --cm -m \
 -g LRGASP.t2g; \
 ${kallisto} quant-tcc -t 30 --long -P ONT \
 Mouse.${sim}.simulated.shuffled._k-${k}_er/count.mtx \
 -f Mouse.${sim}.simulated.shuffled._k-${k}_er/flens.txt \
 -i LRGASP.k-${k}.v-13.idx \
 -e Mouse.${sim}.simulated.shuffled._k-${k}_er/count.ec.txt \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er
# Out:
# [index] k-mer length: 63
# [index] number of targets: 142,551
# [index] number of k-mers: 123,886,385
# [index] number of equivalence classes loaded from file: 48,526
# [tcc] Parsing transcript-compatibility counts (TCC) file as a matrix file
# [tcc] Matrix dimensions: 1 x 48,526
# [quant] Running EM algorithm...
# [quant] Processing sample/cell 0
# [   em] number of priors does not match number of transcripts.
#         defaulting to uniform priors.
#  done

# %%
#${kallisto} index -i LRGASP.k-${k}.v-13.idx -k ${k} LRGASP.cdna.fasta
 #'PB' #'ONT.R10.4'
#--long --error-rate $er --threshold 0.8
# !kallisto='/home/rebekah/kallisto_devel/kallisto/build/src/kallisto';\
 bustools='bustools/build/src/bustools';\
 k=63;\
 sim='ONT.R10.4';\
 ${kallisto} bus -t 30 -x bulk --long --threshold 0.8 \
 -i LRGASP.k-${k}.v-13.idx Mouse.${sim}.simulated.shuffled.fastq.gz \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er; \
 ${bustools} sort -t 30 Mouse.${sim}.simulated.shuffled._k-${k}_er/output.bus \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er/sorted.bus; \
 ${bustools} count -t 30 Mouse.${sim}.simulated.shuffled._k-${k}_er/sorted.bus \
 -t Mouse.${sim}.simulated.shuffled._k-${k}_er/transcripts.txt \
 -e Mouse.${sim}.simulated.shuffled._k-${k}_er/matrix.ec \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er/count --cm -m \
 -g LRGASP.t2g; \
 ${kallisto} quant-tcc -t 30 --long -P ONT \
 Mouse.${sim}.simulated.shuffled._k-${k}_er/count.mtx \
 -f Mouse.${sim}.simulated.shuffled._k-${k}_er/flens.txt \
 -i LRGASP.k-${k}.v-13.idx \
 -e Mouse.${sim}.simulated.shuffled._k-${k}_er/count.ec.txt \
 -o Mouse.${sim}.simulated.shuffled._k-${k}_er
# Out:
# [index] k-mer length: 63
# [index] number of targets: 142,551
# [index] number of k-mers: 123,886,385
# [index] number of equivalence classes loaded from file: 123,605
# [tcc] Parsing transcript-compatibility counts (TCC) file as a matrix file
# [tcc] Matrix dimensions: 1 x 123,605
# [quant] Running EM algorithm...
# [quant] Processing sample/cell 0
# [   em] number of priors does not match number of transcripts.
#         defaulting to uniform priors.
#  done

# %%
from scipy.io import mmread
import pandas as pd
import numpy as np

def LRGASP_comp(sim_name, k):
    count = mmread('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/matrix.abundance.mtx')
    labels = pd.read_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/transcripts.txt', header=None, sep='\t')
    count_bus = pd.DataFrame(count.todense().T, columns=['bus_counts'])
    count_bus['transcript_id'] = [labels.values[i][0] for i in range(np.shape(labels.values)[0])]
    count_bus.index.name = 'transcript_id'
    count_bus.to_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er_bus_quant_tcc.tsv', sep="\t", columns=['transcript_id','bus_counts'], header=1, index=0)

    count = mmread('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/lr_quant_tcc/matrix.abundance.mtx')
    labels = pd.read_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/transcripts.txt', header=None, sep='\t')

    count_bus = pd.DataFrame(count.todense().T, columns=['bus_counts'])
    count_bus['transcript_id'] = [labels.values[i][0] for i in range(np.shape(labels.values)[0])]

    count_bus.index.name = 'transcript_id'
    count_bus.to_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er_bus_lr_quant_tcc.tsv', sep="\t", columns=['transcript_id','bus_counts'], header=1, index=0)
    

def LRGASP_comp_ONT(sim_name, k):
    count = mmread('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/matrix.abundance.mtx')
    labels = pd.read_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/transcripts.txt', header=None, sep='\t')

    count_bus = pd.DataFrame(count.todense().T, columns=['bus_counts'])
    count_bus['transcript_id'] = [labels.values[i][0] for i in range(np.shape(labels.values)[0])]
    count_bus.index.name = 'transcript_id'
    count_bus.to_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er_bus_quant_tcc.tsv', sep="\t", columns=['transcript_id','bus_counts'], header=1, index=0)

    
    count = mmread('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/lr_quant_tcc/matrix.abundance.mtx')
    labels = pd.read_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er/transcripts.txt', header=None, sep='\t')

    count_bus = pd.DataFrame(count.todense().T, columns=['bus_counts'])
    count_bus['transcript_id'] = [labels.values[i][0] for i in range(np.shape(labels.values)[0])]

    count_bus.index.name = 'transcript_id'
    count_bus.to_csv('Mouse.'+sim_name+'.simulated.shuffled._k-'+k+'_er_bus_lr_quant_tcc.tsv', sep="\t", columns=['transcript_id','bus_counts'], header=1, index=0)
    
LRGASP_comp("PB",str(63))
LRGASP_comp_ONT("ONT.R10.4",str(63))

# %%
import scipy
import pandas as pd
import numpy as np
from permetrics.regression import RegressionMetric
import matplotlib.pyplot as plt

def c_ccc(y_pred,y_true):
    cor = np.corrcoef(y_true, y_pred)[0][1]
    # Means
    mean_true = np.mean(y_true)
    mean_pred = np.mean(y_pred)
    # Population variances
    var_true = np.var(y_true)
    var_pred = np.var(y_pred)
    # Population standard deviations
    sd_true = np.std(y_true)
    sd_pred = np.std(y_pred)
    # Calculate CCC
    numerator = 2 * cor * sd_true * sd_pred
    denominator = var_true + var_pred + (mean_true - mean_pred)**2
    ccc = numerator / denominator
    return ccc

def pearson_corr(sim, k):
    count_bus = pd.read_csv(
        "Mouse." + sim + ".simulated.shuffled._k-" + k + "_er_bus_quant_tcc.tsv",
        header=0,
        sep="\t",
    )

    count_bus_sirv = pd.read_csv(
        "Mouse." + sim + ".simulated.shuffled._k-" + k + "_er_bus_lr_quant_tcc_sirv.tsv",
        header=0,
        sep="\t",
    )
    
    count_oar = pd.read_csv(
        "Mouse." + sim + ".oarfish.quant",
        header=0,
        sep="\t",
        names=['transcript_id', 'length', 'oar_count'],
    )
    count_bambu = pd.read_csv(
        "Mouse_"+sim+"/counts_transcript_ENSMUST.txt",
        header=0,
        sep="\t",
        names=['transcript_id', 'gene_id', 'bambu_count'],
    )
    count_bambu_qO = pd.read_csv(
        "Mouse_"+sim+"_quantOnly/counts_transcript.txt",
        header=0,
        sep="\t",
        names=['transcript_id', 'gene_id', 'bambu_count_qO'],
    )
    count_sim = pd.read_csv(
        "Mouse." + sim + ".simulated.shuffled.csv",
        header=0,
        sep="\t",
        names=["transcript_id", "est_count"],
    )
    # IsoQuant_Mouse_IQ_${sim}
    count_iso = pd.read_csv(
        "IsoQuant_Mouse_IQ_"
        + sim
        + "/IsoQuant_Mouse_IQ_"
        + sim
        + "/IsoQuant_Mouse_IQ_"
        + sim
        + ".transcript_counts.tsv",
        header=0, skipfooter=3,
        sep="\t",
        names=["transcript_id", "iso_count"],
    )
    print("count_iso: ", count_iso)
    print(count_bus_sirv)
    
    count = count_sim.merge(count_bus, how="outer", on="transcript_id")
    count = count.merge(count_iso, how="outer", on="transcript_id")
    count = count.merge(count_oar, how="outer", on="transcript_id")
    count = count.merge(count_bambu, how="outer", on="transcript_id")
    count = count.merge(count_bambu_qO, how="outer", on="transcript_id")
    count = count.fillna(0)
    print(count)

    x = count["bus_counts"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    #print(sim+'_k-'+k)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 

    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("lr-kallisto transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")  
    plt.title("lr-kallisto")
    plt.legend()
    plt.savefig(sim+'kallisto_lr_tlc_hex.png', dpi=300)
    plt.show()
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    # y, x = y/np.sum(y)*10000000 + 1,x/np.sum(x)*10000000 + 1
    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print(sim + "_k-" + k)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    x = count["bambu_count"]+1
    y = count["est_count"]+1
    
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    # y, x = y/np.sum(y)*10000000 + 1,x/np.sum(x)*10000000 + 1
    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("bambu ", sim)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    x = count["bambu_count_qO"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 
    
    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("Bambu transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("Bambu")
    plt.legend()
    plt.savefig(sim+'bambu_tlc_hex.png', dpi=300)
    plt.show()
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("bambu quantOnly ", sim)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    x = count["oar_count"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 
 

    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("Oarfish transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("Oarfish")
    plt.legend()
    plt.savefig(sim+'oarfish_tlc_hex.png', dpi=300)
    plt.show()
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("oarfish: "+sim)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    
    x = count["iso_count"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 

    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("IsoQuant transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("IsoQuant")
    plt.legend()
    plt.savefig(sim+'isoquant_tlc_hex.png', dpi=300)
    plt.show()
    
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("IsoQuant: " + sim + "_k-" + k)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    count_bus_lr = pd.read_csv(
        "Mouse." + sim + ".simulated.shuffled._k-" + k + "_er_bus_lr_quant_tcc.tsv",
        header=0,
        sep="\t",
    )

    count = count_sim.merge(count_bus_lr, how="outer", on="transcript_id")
    count = count.fillna(0)

    x = count["bus_counts"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 
    
    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("lr-kallisto transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("lr-kallisto")
    plt.legend()
    plt.savefig(sim+'klr_tlc_ln_hex.png', dpi=300)
    plt.show()


def pearson_corr_ONT(sim, k):
    count_bus = pd.read_csv(
        "Mouse." + sim + ".simulated.shuffled._k-" + k + "_er_bus_quant_tcc.tsv",
        header=0,
        sep="\t",
    )
    count_bambu = pd.read_csv(
        "Mouse_"+sim+"/counts_transcript.txt",
        header=0,
        sep="\t",
        names=['transcript_id', 'gene_id', 'bambu_count'],
    )
    count_oar = pd.read_csv(
        "Mouse." + sim + ".oarfish.quant",
        header=0,
        sep="\t",
        names=['transcript_id', 'length', 'oar_count'],
    )

    count_oar_nuf = pd.read_csv(
        "Mouse." + sim + ".notuf.oarfish.quant",
        header=0,
        sep="\t",
        names=['transcript_id', 'length', 'oar_count_nuf'],
    )
    
    count_sim = pd.read_csv(
        "Mouse." + sim + ".simulated.shuffled.tsv",
        header=0,
        sep="\t",
        names=["transcript_id", "est_count"],
    )
    # IsoQuant_Mouse_IQ_${sim}
    count_iso = pd.read_csv(
        "IsoQuant_Mouse_IQ_"
        + sim
        + "/IsoQuant_Mouse_IQ_"
        + sim
        + "/IsoQuant_Mouse_IQ_"
        + sim
        + ".transcript_counts.tsv",
        header=0, skipfooter=3,
        sep="\t",
        names=["transcript_id", "iso_count"],
    )
    print("count_iso: ", count_iso)

    labels = pd.read_csv('Mouse.'+sim+'.simulated.shuffled._k-'+k+'_er/transcripts.txt', header=None, sep='\t')

    count_bus['transcript_id'] = [labels.values[i][0].split('.')[0] for i in range(np.shape(labels.values)[0])]
    count_iso['transcript_id'] = [count_iso['transcript_id'].values[i].split('.')[0] for i in range(np.shape(count_iso['transcript_id'].values)[0])]
    count_oar['transcript_id'] = [count_oar['transcript_id'].values[i].split('.')[0] for i in range(np.shape(count_oar['transcript_id'].values)[0])]
    count_bambu['transcript_id'] = [count_bambu['transcript_id'].values[i].split('.')[0] for i in range(np.shape(count_bambu['transcript_id'].values)[0])]
    count_oar_nuf['transcript_id'] = [count_oar_nuf['transcript_id'].values[i].split('.')[0] for i in range(np.shape(count_oar_nuf['transcript_id'].values)[0])]
    
    
    print("count_iso: ", count_iso)
    count = count_bus.merge(count_iso, how="outer", on="transcript_id")
    print(count)
    count = count.merge(count_sim, how="outer", on="transcript_id")
    count = count.fillna(0)
    print(count)

    count = count.merge(count_bambu, how="outer", on="transcript_id")
    count = count.fillna(0)
    print(count)
    
    count = count.merge(count_oar, how="outer", on="transcript_id")
    count = count.fillna(0)
    print(count)

    count = count.merge(count_oar_nuf, how="outer", on="transcript_id")
    count = count.fillna(0)
    print(count)

    x = count["bus_counts"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 


    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("lr-kallisto transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("lr-kallisto")
    plt.legend()
    plt.savefig(sim+'klr_tlc_hex.png', dpi=300)
    plt.show()
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print(sim + "_k-" + k)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    x = count["bambu_count"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 
    
    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("bambu transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("Bambu")
    plt.legend()
    plt.savefig(sim+'bambu_tlc_hex.png', dpi=300)
    plt.show()
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("bambu ", sim)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    x = count["oar_count"]+1
    y = count["est_count"]+1

    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())
    # y, x = y/np.sum(y)*10000000 + 1,x/np.sum(x)*10000000 + 1

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("oarfish: "+sim)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    x = count["oar_count_nuf"]+1
    y = count["est_count"]+1

    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 


    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("Oarfish transcript-level count")
    plt.ylabel("Ground Truth transcript-level count)")
    plt.title("Oarfish")
    plt.legend()
    plt.savefig(sim+'oarfish_tlc_hex.png', dpi=300)
    plt.show()

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("oarfish not -u f: "+sim)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    
    x = count["iso_count"]+1
    y = count["est_count"]+1
    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 

    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("IsoQuant transcript-level count")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("IsoQuant")
    plt.legend()
    plt.savefig(sim+'isoquant_tlc_hex.png', dpi=300)
    plt.show()
    
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print("IsoQuant: " + sim)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)

    count_bus_lr = pd.read_csv(
        "Mouse." + sim + ".simulated.shuffled._k-" + k + "_er_bus_lr_quant_tcc.tsv",
        header=0,
        sep="\t",
    )
    # count_sim = pd.read_csv("LRGASP.transcript.expression", header=0, sep='\t')
    count_bus_lr['transcript_id'] = [labels.values[i][0].split('.')[0] for i in range(np.shape(labels.values)[0])]
    count = count_sim.merge(count_bus_lr, how="outer", on="transcript_id")
    count = count.fillna(0)

    x = count["bus_counts"]+1
    y = count["est_count"]+1

    r, p = scipy.stats.pearsonr(x,y)   # Pearson's r
    rho = scipy.stats.spearmanr(x,y).correlation   # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau
    m, b = np.polyfit(x, y, 1)

    ccc = c_ccc(x,y)
        
    print("CCC",ccc)
    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    nrmse = evaluator.normalized_root_mean_square_error()
    #print(sim+'_k-'+k)
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)
    plt.plot([i for i in range(0, 100000)],[i for i in range(0, 100000)], label='y=x\nCCC '+str(round(ccc,2))+'\nNRMSE '+str(round(nrmse, 2))+'\nPearson R '+str(round(r,2))+'\nSpearman '+r"$\rho$"+' '+str(round(rho,2))) 

    plt.hexbin(x, y, gridsize=100, cmap='jet', bins='log', xscale='log', yscale='log')
    plt.colorbar(label='counts')
    plt.xlabel("lr-kallisto transcript-level count)")
    plt.ylabel("Ground Truth transcript-level count")
    plt.title("lr-kallisto")
    plt.legend()
    plt.savefig(sim+'klr_tlc_ln_hex.png', dpi=300)
    plt.show()

    evaluator = RegressionMetric(np.array(y), np.array(x), decimal=5)
    print(evaluator.normalized_root_mean_square_error())

    r, p = scipy.stats.pearsonr(x, y)  # Pearson's r
    rho = scipy.stats.spearmanr(x, y)[0]  # Spearman's rho
    tau = scipy.stats.kendalltau(x, y)[0]  # Kendall's tau

    print(sim + "_k-" + k + " Length normalized")
    print("Pearson's r:\t", r)
    print("Spearman's rho:\t", rho)
    print("Kendall's tau:\t", tau)


#pearson_corr("PB", str(47))
pearson_corr("PB", str(63))
pearson_corr_ONT("ONT.R10.4", str(63))
#pearson_corr_ONT("ONT.R10.4", str(31))
# pearson_corr_ONT("ONT.R10.4", str(41))
#pearson_corr_ONT("ONT.R10.4", str(31))
# Out:
# /tmp/ipykernel_228965/3121814195.py:62: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   count_iso = pd.read_csv(
# count_iso:                 transcript_id  iso_count
# 0       ENSMUST00000000834.4        2.0
# 1      ENSMUST00000001166.14      112.0
# 2      ENSMUST00000001172.12      110.0
# 3       ENSMUST00000001339.6      117.0
# 4      ENSMUST00000001724.12      115.0
# ...                      ...        ...
# 34755   ENSMUST00000189201.2        8.0
# 34756   ENSMUST00000191652.2        9.0
# 34757   ENSMUST00000238471.2       43.0
# 34758   ENSMUST00000238676.2        2.0
# 34759   ENSMUST00000238758.2      721.5
#
# [34760 rows x 2 columns]
#    transcript_id  bus_counts
# 0        SIRV101         0.0
# 1        SIRV102         0.0
# 2        SIRV103         0.0
# 3        SIRV105         0.0
# 4        SIRV106         0.0
# ..           ...         ...
# 79     SIRV10002         0.0
# 80     SIRV10003         0.0
# 81     SIRV12001         0.0
# 82     SIRV12002         0.0
# 83     SIRV12003         0.0
#
# [84 rows x 2 columns]
#                transcript_id  est_count  bus_counts  iso_count  length  \
# 0       ENSMUST00000082908.3        0.0         0.0        0.0   110.0
# 1       ENSMUST00000070533.5        6.0         6.0        0.0  3634.0
# 2       ENSMUST00000159265.2        0.0         0.0        0.0  2989.0
# 3       ENSMUST00000162897.2        0.0         0.0        0.0  4153.0
# 4       ENSMUST00000192857.2        0.0         0.0        0.0   480.0
# ...                      ...        ...         ...        ...     ...
# 142567  ENSMUST00000175005.4        2.0         0.0        0.0     0.0
# 142568  ENSMUST00000240208.1        2.0         0.0        0.0     0.0
# 142569  ENSMUST00000240143.1        4.0         0.0        0.0     0.0
# 142570  ENSMUST00000184254.8        2.0         0.0        0.0     0.0
# 142571  ENSMUST00000193812.2        0.0         0.0        0.0  1070.0
#
#         oar_count             gene_id_x  bambu_count             gene_id_y  \
# 0             0.0  ENSMUSG00000064842.3          0.0  ENSMUSG00000064842.3
# 1             6.0  ENSMUSG00000051951.6         17.0  ENSMUSG00000051951.6
# 2             0.0  ENSMUSG00000051951.6          0.0  ENSMUSG00000051951.6
# 3             0.0  ENSMUSG00000051951.6          0.0  ENSMUSG00000051951.6
# 4             0.0  ENSMUSG00000102851.2          0.0  ENSMUSG00000102851.2
# ...           ...                   ...          ...                   ...
# 142567        0.0                     0          0.0                     0
# 142568        0.0                     0          0.0                     0
# 142569        0.0                     0          0.0                     0
# 142570        0.0                     0          0.0                     0
# 142571        0.0  ENSMUSG00000102693.2          0.0  ENSMUSG00000102693.2
#
#         bambu_count_qO
# 0                  0.0
# 1                 17.0
# 2                  0.0
# 3                  0.0
# 4                  0.0
# ...                ...
# 142567             0.0
# 142568             0.0
# 142569             0.0
# 142570             0.0
# 142571             0.0
#
# [142572 rows x 10 columns]
# CCC 0.9847525474140658
# Pearson's r:	 0.9850019494050473
# Spearman's rho:	 0.9695287442982965
# Kendall's tau:	 0.9570239022476847
# 0.17652
# PB_k-63
# Pearson's r:	 0.9850019494050473
# Spearman's rho:	 0.9695287442982965
# Kendall's tau:	 0.9570239022476847
# 0.47615
# bambu  PB
# Pearson's r:	 0.9293124180583678
# Spearman's rho:	 0.9639659787757097
# Kendall's tau:	 0.9469389580983577
# CCC 0.9098195554249684
# Pearson's r:	 0.9293440068950982
# Spearman's rho:	 0.9639010507949687
# Kendall's tau:	 0.9469040990487128
# 0.47586
# bambu quantOnly  PB
# Pearson's r:	 0.9293440068950982
# Spearman's rho:	 0.9639010507949687
# Kendall's tau:	 0.9469040990487128
# CCC 0.7917702089067344
# Pearson's r:	 0.8306903321592941
# Spearman's rho:	 0.8854080598835804
# Kendall's tau:	 0.8464869902101457
# 0.56836
# oarfish: PB
# Pearson's r:	 0.8306903321592941
# Spearman's rho:	 0.8854080598835804
# Kendall's tau:	 0.8464869902101457
# CCC 0.9044782891707887
# Pearson's r:	 0.9050256356848582
# Spearman's rho:	 0.9797657106054738
# Kendall's tau:	 0.9750380421699373
# 0.44489
# IsoQuant: PB_k-63
# Pearson's r:	 0.9050256356848582
# Spearman's rho:	 0.9797657106054738
# Kendall's tau:	 0.9750380421699373
# CCC 0.9857451988728746
# Pearson's r:	 0.9860435609058859
# Spearman's rho:	 0.9723970261228969
# Kendall's tau:	 0.9603033692609669
# /tmp/ipykernel_228965/3121814195.py:322: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   count_iso = pd.read_csv(
# count_iso:                 transcript_id  iso_count
# 0       ENSMUST00000000834.4       8.00
# 1      ENSMUST00000001166.14     560.33
# 2      ENSMUST00000001172.12     498.00
# 3       ENSMUST00000001339.6     620.50
# 4      ENSMUST00000001724.12     577.50
# ...                      ...        ...
# 39475   ENSMUST00000189201.2      62.00
# 39476   ENSMUST00000191652.2      63.00
# 39477   ENSMUST00000238471.2     730.00
# 39478   ENSMUST00000238676.2      10.00
# 39479   ENSMUST00000238758.2     696.25
#
# [39480 rows x 2 columns]
# count_iso:              transcript_id  iso_count
# 0      ENSMUST00000000834       8.00
# 1      ENSMUST00000001166     560.33
# 2      ENSMUST00000001172     498.00
# 3      ENSMUST00000001339     620.50
# 4      ENSMUST00000001724     577.50
# ...                   ...        ...
# 39475  ENSMUST00000189201      62.00
# 39476  ENSMUST00000191652      63.00
# 39477  ENSMUST00000238471     730.00
# 39478  ENSMUST00000238676      10.00
# 39479  ENSMUST00000238758     696.25
#
# [39480 rows x 2 columns]
#              transcript_id  bus_counts  iso_count
# 0       ENSMUST00000193812         0.0        NaN
# 1       ENSMUST00000082908         0.0        NaN
# 2       ENSMUST00000070533        36.0        NaN
# 3       ENSMUST00000159265         0.0        NaN
# 4       ENSMUST00000162897         0.0        NaN
# ...                    ...         ...        ...
# 142546           SIRV10002         0.0        NaN
# 142547           SIRV10003         0.0        NaN
# 142548           SIRV12001         0.0        NaN
# 142549           SIRV12002         0.0        NaN
# 142550           SIRV12003         0.0        NaN
#
# [142551 rows x 3 columns]
#              transcript_id  bus_counts  iso_count  est_count
# 0       ENSMUST00000193812         0.0        0.0        0.0
# 1       ENSMUST00000082908         0.0        0.0        0.0
# 2       ENSMUST00000070533        36.0        0.0       36.0
# 3       ENSMUST00000159265         0.0        0.0        0.0
# 4       ENSMUST00000162897         0.0        0.0        0.0
# ...                    ...         ...        ...        ...
# 142555  ENSMUST00000240271         0.0        0.0        3.0
# 142556  ENSMUST00000184254         0.0        0.0        2.0
# 142557  ENSMUST00000240208         0.0        0.0        1.0
# 142558  ENSMUST00000240247         0.0        0.0        3.0
# 142559  ENSMUST00000240143         0.0        0.0        2.0
#
# [142560 rows x 4 columns]
#              transcript_id  bus_counts  iso_count  est_count  \
# 0       ENSMUST00000193812         0.0        0.0        0.0
# 1       ENSMUST00000082908         0.0        0.0        0.0
# 2       ENSMUST00000070533        36.0        0.0       36.0
# 3       ENSMUST00000159265         0.0        0.0        0.0
# 4       ENSMUST00000162897         0.0        0.0        0.0
# ...                    ...         ...        ...        ...
# 142555  ENSMUST00000240271         0.0        0.0        3.0
# 142556  ENSMUST00000184254         0.0        0.0        2.0
# 142557  ENSMUST00000240208         0.0        0.0        1.0
# 142558  ENSMUST00000240247         0.0        0.0        3.0
# 142559  ENSMUST00000240143         0.0        0.0        2.0
#
#                      gene_id  bambu_count
# 0       ENSMUSG00000102693.2          0.0
# 1       ENSMUSG00000064842.3          0.0
# 2       ENSMUSG00000051951.6         61.0
# 3       ENSMUSG00000051951.6          0.0
# 4       ENSMUSG00000051951.6          0.0
# ...                      ...          ...
# 142555                     0          0.0
# 142556                     0          0.0
# 142557                     0          0.0
# 142558                     0          0.0
# 142559                     0          0.0
#
# [142560 rows x 6 columns]
#              transcript_id  bus_counts  iso_count  est_count  \
# 0       ENSMUST00000193812         0.0        0.0        0.0
# 1       ENSMUST00000082908         0.0        0.0        0.0
# 2       ENSMUST00000070533        36.0        0.0       36.0
# 3       ENSMUST00000159265         0.0        0.0        0.0
# 4       ENSMUST00000162897         0.0        0.0        0.0
# ...                    ...         ...        ...        ...
# 142555  ENSMUST00000240271         0.0        0.0        3.0
# 142556  ENSMUST00000184254         0.0        0.0        2.0
# 142557  ENSMUST00000240208         0.0        0.0        1.0
# 142558  ENSMUST00000240247         0.0        0.0        3.0
# 142559  ENSMUST00000240143         0.0        0.0        2.0
#
#                      gene_id  bambu_count  length  oar_count
# 0       ENSMUSG00000102693.2          0.0  1070.0        0.0
# 1       ENSMUSG00000064842.3          0.0   110.0        0.0
# 2       ENSMUSG00000051951.6         61.0  3634.0       12.0
# 3       ENSMUSG00000051951.6          0.0  2989.0        3.0
# 4       ENSMUSG00000051951.6          0.0  4153.0        2.0
# ...                      ...          ...     ...        ...
# 142555                     0          0.0     0.0        0.0
# 142556                     0          0.0     0.0        0.0
# 142557                     0          0.0     0.0        0.0
# 142558                     0          0.0     0.0        0.0
# 142559                     0          0.0     0.0        0.0
#
# [142560 rows x 8 columns]
#              transcript_id  bus_counts  iso_count  est_count  \
# 0       ENSMUST00000193812         0.0        0.0        0.0
# 1       ENSMUST00000082908         0.0        0.0        0.0
# 2       ENSMUST00000070533        36.0        0.0       36.0
# 3       ENSMUST00000159265         0.0        0.0        0.0
# 4       ENSMUST00000162897         0.0        0.0        0.0
# ...                    ...         ...        ...        ...
# 142555  ENSMUST00000240271         0.0        0.0        3.0
# 142556  ENSMUST00000184254         0.0        0.0        2.0
# 142557  ENSMUST00000240208         0.0        0.0        1.0
# 142558  ENSMUST00000240247         0.0        0.0        3.0
# 142559  ENSMUST00000240143         0.0        0.0        2.0
#
#                      gene_id  bambu_count  length_x  oar_count  length_y  \
# 0       ENSMUSG00000102693.2          0.0    1070.0        0.0    1070.0
# 1       ENSMUSG00000064842.3          0.0     110.0        0.0     110.0
# 2       ENSMUSG00000051951.6         61.0    3634.0       12.0    3634.0
# 3       ENSMUSG00000051951.6          0.0    2989.0        3.0    2989.0
# 4       ENSMUSG00000051951.6          0.0    4153.0        2.0    4153.0
# ...                      ...          ...       ...        ...       ...
# 142555                     0          0.0       0.0        0.0       0.0
# 142556                     0          0.0       0.0        0.0       0.0
# 142557                     0          0.0       0.0        0.0       0.0
# 142558                     0          0.0       0.0        0.0       0.0
# 142559                     0          0.0       0.0        0.0       0.0
#
#         oar_count_nuf
# 0                 0.0
# 1                 0.0
# 2                36.0
# 3                12.0
# 4                18.0
# ...               ...
# 142555            0.0
# 142556            0.0
# 142557            0.0
# 142558            0.0
# 142559            0.0
#
# [142560 rows x 10 columns]
# CCC 0.971812711380365
# Pearson's r:	 0.9718574976700539
# Spearman's rho:	 0.9196712637118073
# Kendall's tau:	 0.8845339718062757
# 0.23847
# ONT.R10.4_k-63
# Pearson's r:	 0.9718574976700539
# Spearman's rho:	 0.9196712637118073
# Kendall's tau:	 0.8845339718062757
# CCC 0.8822620799059765
# Pearson's r:	 0.8925246517909956
# Spearman's rho:	 0.9044623045862304
# Kendall's tau:	 0.8647841592999508
# 0.52659
# bambu  ONT.R10.4
# Pearson's r:	 0.8925246517909956
# Spearman's rho:	 0.9044623045862304
# Kendall's tau:	 0.8647841592999508
# 2.24506
# oarfish: ONT.R10.4
# Pearson's r:	 0.9422495304157701
# Spearman's rho:	 0.7957024980395309
# Kendall's tau:	 0.7452212499018128
# CCC 0.7181514385008749
# Pearson's r:	 0.7788409050359655
# Spearman's rho:	 0.6952994261682237
# Kendall's tau:	 0.6195145140686231
# oarfish not -u f: ONT.R10.4
# Pearson's r:	 0.7788409050359655
# Spearman's rho:	 0.6952994261682237
# Kendall's tau:	 0.6195145140686231
# CCC 0.9091055536850428
# Pearson's r:	 0.9127416946472103
# Spearman's rho:	 0.8980256386580063
# Kendall's tau:	 0.8686619591955687
# 0.44673
# IsoQuant: ONT.R10.4
# Pearson's r:	 0.9127416946472103
# Spearman's rho:	 0.8980256386580063
# Kendall's tau:	 0.8686619591955687
# CCC 0.9456022665632808
# Pearson's r:	 0.957125708476653
# Spearman's rho:	 0.9144625088661109
# Kendall's tau:	 0.880776893217307
# 0.35863
# ONT.R10.4_k-63 Length normalized
# Pearson's r:	 0.957125708476653
# Spearman's rho:	 0.9144625088661109
# Kendall's tau:	 0.880776893217307
